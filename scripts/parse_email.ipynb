# %%
import os
import email
import pandas as pd

# %%
MAILDIR_PATH = "../maildir"

# %%
def parse_email(file_path):

    with open(file_path, "r", encoding="latin-1") as f:
        msg = email.message_from_file(f)

    email_data = {
        "from": msg.get("From"),
        "to": msg.get("To"),
        "date": msg.get("Date"),
        "subject": msg.get("Subject"),
        "message_id": msg.get("Message-ID"),
        "in_reply_to": msg.get("In-Reply-To"),
        "body": msg.get_payload()
    }

    return email_data

# %%
emails = []

for root, dirs, files in os.walk(MAILDIR_PATH):

    for file in files:

        file_path = os.path.join(root, file)

        try:
            email_data = parse_email(file_path)
            emails.append(email_data)

        except Exception as e:
            print("Error:", file_path)

# %%
df = pd.DataFrame(emails)

print(df.head())
print("Total emails:", len(df))

df.to_csv("../data/emails.csv", index=False)
# Out:
#                               from  \
# 0          chris.germany@enron.com
# 1          chris.germany@enron.com
# 2    enron.announcements@enron.com
# 3         michael.garred@enron.com
# 4  dkinney@columbiaenergygroup.com
#
#                                                   to  \
# 0                                                NaN
# 1                                                NaN
# 2                               enron.mail@enron.com
# 3                            chris.germany@enron.com
# 4  kevin.ruscitti@enron.com, chris.germany@enron.com
#
#                                     date  \
# 0  Tue, 22 May 2001 11:57:10 -0700 (PDT)
# 1  Thu, 17 May 2001 17:05:00 -0700 (PDT)
# 2  Sun, 30 Apr 2000 23:14:00 -0700 (PDT)
# 3  Thu, 19 Oct 2000 06:49:00 -0700 (PDT)
# 4  Thu, 31 Aug 2000 03:49:00 -0700 (PDT)
#
#                                              subject  \
# 0                          Don't forget to register!
# 1                          Don't forget to register!
# 2  EnronAssistance Travel & Medical Emergency Pro...
# 3                       Re: New Capacity for Nov-Oct
# 4          CES Daily Requirements for 8/31 and after
#
#                                       message_id in_reply_to  \
# 0  <10655503.1075840536001.JavaMail.evans@thyme>        None
# 1   <7042248.1075840536024.JavaMail.evans@thyme>        None
# 2  <32235109.1075853782527.JavaMail.evans@thyme>        None
# 3  <14518277.1075853782480.JavaMail.evans@thyme>        None
# 4    <862390.1075853782505.JavaMail.evans@thyme>        None
#
#                                                 body
# 0  To register your Palm Computing\n organizer el...
# 1  \tTASK ASSIGNMENT\n\n\nTask Priority:\t\t1\nTa...
# 2  Beginning May 1, 2000, International SOS will ...
# 3  Everything looks fine with one exception.  The...
# 4  The attached files contains our daily volume r...
# Total emails: 517401
